# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style()
# %matplotlib inline

import warnings
warnings.filterwarnings("ignore")

# %%
import os

df=pd.read_csv('Airplane_Crashes_and_Fatalities_Since_1908.csv')

# %%
df
# Out:
#             Date   Time                                           Location  \
# 0     09/17/1908  17:18                                Fort Myer, Virginia
# 1     07/12/1912  06:30                            AtlantiCity, New Jersey
# 2     08/06/1913    NaN                 Victoria, British Columbia, Canada
# 3     09/09/1913  18:30                                 Over the North Sea
# 4     10/17/1913  10:30                         Near Johannisthal, Germany
# ...          ...    ...                                                ...
# 5263  05/20/2009  06:30                             Near Madiun, Indonesia
# 5264  05/26/2009    NaN                  Near Isiro, DemocratiRepubliCongo
# 5265  06/01/2009  00:15  AtlantiOcean, 570 miles northeast of Natal, Br...
# 5266  06/07/2009  08:30       Near Port Hope Simpson, Newfoundland, Canada
# 5267  06/08/2009    NaN                  State of Arunachal Pradesh, India
#
#                              Operator Flight #  \
# 0                Military - U.S. Army      NaN
# 1                Military - U.S. Navy      NaN
# 2                             Private        -
# 3              Military - German Navy      NaN
# 4              Military - German Navy      NaN
# ...                               ...      ...
# 5263  Military - Indonesian Air Force      NaN
# 5264                      Service Air      NaN
# 5265                       Air France      447
# 5266                       Strait Air      NaN
# 5267      Military - Indian Air Force      NaN
#
#                                           Route  \
# 0                                 Demonstration
# 1                                   Test flight
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# ...                                         ...
# 5263                           Jakarta - Maduin
# 5264                               Goma - Isiro
# 5265                     Rio de Janeiro - Paris
# 5266  Lourdes de BlanSablon - Port Hope Simpson
# 5267                         Mechuka for Jorhat
#
#                                   Type Registration cn/In  Aboard  Fatalities  \
# 0                     Wright Flyer III          NaN     1     2.0         1.0
# 1                            Dirigible          NaN   NaN     5.0         5.0
# 2                     Curtiss seaplane          NaN   NaN     1.0         1.0
# 3               Zeppelin L-1 (airship)          NaN   NaN    20.0        14.0
# 4               Zeppelin L-2 (airship)          NaN   NaN    30.0        30.0
# ...                                ...          ...   ...     ...         ...
# 5263           Lockheed C-130 Hercules       A-1325  1982   112.0        98.0
# 5264                     Antonov An-26       9Q-CSA  5005     4.0         4.0
# 5265                   Airbus A330-203       F-GZCP   660   228.0       228.0
# 5266  Britten-Norman BN-2A-27 Islander      C-FJJR    424     1.0         1.0
# 5267                     Antonov An-32          NaN   NaN    13.0        13.0
#
#       Ground                                            Summary
# 0        0.0  During a demonstration flight, a U.S. Army fly...
# 1        0.0  First U.S. dirigible Akron exploded just offsh...
# 2        0.0  The first fatal airplane accident in Canada oc...
# 3        0.0  The airship flew into a thunderstorm and encou...
# 4        0.0  Hydrogen gas which was being vented was sucked...
# ...      ...                                                ...
# 5263     2.0  While on approach, the military transport cras...
# 5264     NaN  The cargo plane crashed while on approach to I...
# 5265     0.0  The Airbus went missing over the AtlantiOcean ...
# 5266     0.0  The air ambulance crashed into hills while att...
# 5267     0.0  The military transport went missing while en r...
#
# [5268 rows x 13 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5268 entries, 0 to 5267
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          5268 non-null   object
#  1   Time          3049 non-null   object
#  2   Location      5248 non-null   object
#  3   Operator      5250 non-null   object
#  4   Flight #      1069 non-null   object
#  5   Route         3562 non-null   object
#  6   Type          5241 non-null   object
#  7   Registration  4933 non-null   object
#  8   cn/In         4040 non-null   object
#  9   Aboard        5246 non-null   float64
#  10  Fatalities    5256 non-null   float64
#  11  Ground        5246 non-null   float64
#  12  Summary       4878 non-null   object
# dtypes: float64(3), object(10)
# memory usage: 535.2+ KB

# %%
df.shape
# Out:
# (5268, 13)

# %%
df.columns
# Out:
# Index(['Date', 'Time', 'Location', 'Operator', 'Flight #', 'Route', 'Type',
#        'Registration', 'cn/In', 'Aboard', 'Fatalities', 'Ground', 'Summary'],
#       dtype='object')

# %%
df.describe().T
# Out:
#              count       mean        std  min  25%   50%   75%     max
# Aboard      5246.0  27.554518  43.076711  0.0  5.0  13.0  30.0   644.0
# Fatalities  5256.0  20.068303  33.199952  0.0  3.0   9.0  23.0   583.0
# Ground      5246.0   1.608845  53.987827  0.0  0.0   0.0   0.0  2750.0

# %%
df.isnull().sum()
# Out:
# Date               0
# Time            2219
# Location          20
# Operator          18
# Flight #        4199
# Route           1706
# Type              27
# Registration     335
# cn/In           1228
# Aboard            22
# Fatalities        12
# Ground            22
# Summary          390
# dtype: int64

# %%
vals=[]
for col in df.columns:
    vals.append(len(df[col].unique()))
pd.DataFrame(data=vals,index=df.columns,columns=['Unique_Values'])
# Out:
#               Unique_Values
# Date                   4753
# Time                   1006
# Location               4304
# Operator               2477
# Flight #                725
# Route                  3245
# Type                   2447
# Registration           4906
# cn/In                  3708
# Aboard                  240
# Fatalities              192
# Ground                   51
# Summary                4674

# %%
perc_na = pd.Series(round(df.isnull().sum()/len(df), 3), name='Percentage_of_NA')
num_na = pd.Series(df.isnull().sum(),name='Number_of_NA')
pd.concat([perc_na,num_na],axis=1)
# Out:
#               Percentage_of_NA  Number_of_NA
# Date                     0.000             0
# Time                     0.421          2219
# Location                 0.004            20
# Operator                 0.003            18
# Flight #                 0.797          4199
# Route                    0.324          1706
# Type                     0.005            27
# Registration             0.064           335
# cn/In                    0.233          1228
# Aboard                   0.004            22
# Fatalities               0.002            12
# Ground                   0.004            22
# Summary                  0.074           390

# %%
# Printing anonymous values in Time Variable.
for i in df.Time.dropna():
    try:
        pd.to_datetime(i)
    except:
        print(i)
# Out:
# c: 1:00
# c:17:00
# c: 2:00
# c:09:00
# c16:50
# 12'20
# 18.40
# c:09:00
# 114:20
# c14:30
# 0943
# 22'08
# c: 9:40

# %%
# Correcting the anonymous values in Time variable.
df.Time=df.Time.replace({"c: 1:00":'1:00', "c:17:00":'17:00', "c: 2:00":'2:00', "c:09:00":'09:00',
                         "c16:50":'16:50', "12'20":'12:20', "18.40":'18:40', "c:09:00":'09:00',
                         "114:20":'14:20', "c14:30":'14:30', "0943":'09:43', "22'08":'22:08', "c: 9:40":'9:40'})

# %%
df
# Out:
#             Date   Time                                           Location  \
# 0     09/17/1908  17:18                                Fort Myer, Virginia
# 1     07/12/1912  06:30                            AtlantiCity, New Jersey
# 2     08/06/1913    NaN                 Victoria, British Columbia, Canada
# 3     09/09/1913  18:30                                 Over the North Sea
# 4     10/17/1913  10:30                         Near Johannisthal, Germany
# ...          ...    ...                                                ...
# 5263  05/20/2009  06:30                             Near Madiun, Indonesia
# 5264  05/26/2009    NaN                  Near Isiro, DemocratiRepubliCongo
# 5265  06/01/2009  00:15  AtlantiOcean, 570 miles northeast of Natal, Br...
# 5266  06/07/2009  08:30       Near Port Hope Simpson, Newfoundland, Canada
# 5267  06/08/2009    NaN                  State of Arunachal Pradesh, India
#
#                              Operator Flight #  \
# 0                Military - U.S. Army      NaN
# 1                Military - U.S. Navy      NaN
# 2                             Private        -
# 3              Military - German Navy      NaN
# 4              Military - German Navy      NaN
# ...                               ...      ...
# 5263  Military - Indonesian Air Force      NaN
# 5264                      Service Air      NaN
# 5265                       Air France      447
# 5266                       Strait Air      NaN
# 5267      Military - Indian Air Force      NaN
#
#                                           Route  \
# 0                                 Demonstration
# 1                                   Test flight
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# ...                                         ...
# 5263                           Jakarta - Maduin
# 5264                               Goma - Isiro
# 5265                     Rio de Janeiro - Paris
# 5266  Lourdes de BlanSablon - Port Hope Simpson
# 5267                         Mechuka for Jorhat
#
#                                   Type Registration cn/In  Aboard  Fatalities  \
# 0                     Wright Flyer III          NaN     1     2.0         1.0
# 1                            Dirigible          NaN   NaN     5.0         5.0
# 2                     Curtiss seaplane          NaN   NaN     1.0         1.0
# 3               Zeppelin L-1 (airship)          NaN   NaN    20.0        14.0
# 4               Zeppelin L-2 (airship)          NaN   NaN    30.0        30.0
# ...                                ...          ...   ...     ...         ...
# 5263           Lockheed C-130 Hercules       A-1325  1982   112.0        98.0
# 5264                     Antonov An-26       9Q-CSA  5005     4.0         4.0
# 5265                   Airbus A330-203       F-GZCP   660   228.0       228.0
# 5266  Britten-Norman BN-2A-27 Islander      C-FJJR    424     1.0         1.0
# 5267                     Antonov An-32          NaN   NaN    13.0        13.0
#
#       Ground                                            Summary
# 0        0.0  During a demonstration flight, a U.S. Army fly...
# 1        0.0  First U.S. dirigible Akron exploded just offsh...
# 2        0.0  The first fatal airplane accident in Canada oc...
# 3        0.0  The airship flew into a thunderstorm and encou...
# 4        0.0  Hydrogen gas which was being vented was sucked...
# ...      ...                                                ...
# 5263     2.0  While on approach, the military transport cras...
# 5264     NaN  The cargo plane crashed while on approach to I...
# 5265     0.0  The Airbus went missing over the AtlantiOcean ...
# 5266     0.0  The air ambulance crashed into hills while att...
# 5267     0.0  The military transport went missing while en r...
#
# [5268 rows x 13 columns]

# %%
# Converting Time variable from time to part of day type.
hour,mins='',''
def get_hours(time):
    if type(time) == float:
        return 'Unknown'
    
    hour, mins=[int(i) for i in time.split(':')]
    if mins > 30:
        hour+=1
    
    if hour <= 4:
        return'Late Night'
    if hour <= 8:
        return 'Early Morning'
    elif hour <= 12:
        return 'Morning'
    elif hour <= 16:
        return'Noon'
    elif hour <= 20:
        return 'Evening'
    else:
        return'Night'

# %%
df.Time=df.Time.apply(get_hours)

# %%
df
# Out:
#             Date           Time  \
# 0     09/17/1908        Evening
# 1     07/12/1912  Early Morning
# 2     08/06/1913        Unknown
# 3     09/09/1913        Evening
# 4     10/17/1913        Morning
# ...          ...            ...
# 5263  05/20/2009  Early Morning
# 5264  05/26/2009        Unknown
# 5265  06/01/2009     Late Night
# 5266  06/07/2009  Early Morning
# 5267  06/08/2009        Unknown
#
#                                                Location  \
# 0                                   Fort Myer, Virginia
# 1                               AtlantiCity, New Jersey
# 2                    Victoria, British Columbia, Canada
# 3                                    Over the North Sea
# 4                            Near Johannisthal, Germany
# ...                                                 ...
# 5263                             Near Madiun, Indonesia
# 5264                  Near Isiro, DemocratiRepubliCongo
# 5265  AtlantiOcean, 570 miles northeast of Natal, Br...
# 5266       Near Port Hope Simpson, Newfoundland, Canada
# 5267                  State of Arunachal Pradesh, India
#
#                              Operator Flight #  \
# 0                Military - U.S. Army      NaN
# 1                Military - U.S. Navy      NaN
# 2                             Private        -
# 3              Military - German Navy      NaN
# 4              Military - German Navy      NaN
# ...                               ...      ...
# 5263  Military - Indonesian Air Force      NaN
# 5264                      Service Air      NaN
# 5265                       Air France      447
# 5266                       Strait Air      NaN
# 5267      Military - Indian Air Force      NaN
#
#                                           Route  \
# 0                                 Demonstration
# 1                                   Test flight
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# ...                                         ...
# 5263                           Jakarta - Maduin
# 5264                               Goma - Isiro
# 5265                     Rio de Janeiro - Paris
# 5266  Lourdes de BlanSablon - Port Hope Simpson
# 5267                         Mechuka for Jorhat
#
#                                   Type Registration cn/In  Aboard  Fatalities  \
# 0                     Wright Flyer III          NaN     1     2.0         1.0
# 1                            Dirigible          NaN   NaN     5.0         5.0
# 2                     Curtiss seaplane          NaN   NaN     1.0         1.0
# 3               Zeppelin L-1 (airship)          NaN   NaN    20.0        14.0
# 4               Zeppelin L-2 (airship)          NaN   NaN    30.0        30.0
# ...                                ...          ...   ...     ...         ...
# 5263           Lockheed C-130 Hercules       A-1325  1982   112.0        98.0
# 5264                     Antonov An-26       9Q-CSA  5005     4.0         4.0
# 5265                   Airbus A330-203       F-GZCP   660   228.0       228.0
# 5266  Britten-Norman BN-2A-27 Islander      C-FJJR    424     1.0         1.0
# 5267                     Antonov An-32          NaN   NaN    13.0        13.0
#
#       Ground                                            Summary
# 0        0.0  During a demonstration flight, a U.S. Army fly...
# 1        0.0  First U.S. dirigible Akron exploded just offsh...
# 2        0.0  The first fatal airplane accident in Canada oc...
# 3        0.0  The airship flew into a thunderstorm and encou...
# 4        0.0  Hydrogen gas which was being vented was sucked...
# ...      ...                                                ...
# 5263     2.0  While on approach, the military transport cras...
# 5264     NaN  The cargo plane crashed while on approach to I...
# 5265     0.0  The Airbus went missing over the AtlantiOcean ...
# 5266     0.0  The air ambulance crashed into hills while att...
# 5267     0.0  The military transport went missing while en r...
#
# [5268 rows x 13 columns]

# %%
# Getting only the countries from the location variable.
loc=[]
def get_country(location):
    if type(location)==float:
        return "Unknown"
    
    loc=location.split(',')
    return loc[len(loc)-1].replace(" ",'').lower().replace("off ",'')

# %%
df.Location=df.Location.apply(get_country)

# %%
df
# Out:
#             Date           Time               Location  \
# 0     09/17/1908        Evening               virginia
# 1     07/12/1912  Early Morning              newjersey
# 2     08/06/1913        Unknown                 canada
# 3     09/09/1913        Evening        overthenorthsea
# 4     10/17/1913        Morning                germany
# ...          ...            ...                    ...
# 5263  05/20/2009  Early Morning              indonesia
# 5264  05/26/2009        Unknown  democratirepublicongo
# 5265  06/01/2009     Late Night                 brazil
# 5266  06/07/2009  Early Morning                 canada
# 5267  06/08/2009        Unknown                  india
#
#                              Operator Flight #  \
# 0                Military - U.S. Army      NaN
# 1                Military - U.S. Navy      NaN
# 2                             Private        -
# 3              Military - German Navy      NaN
# 4              Military - German Navy      NaN
# ...                               ...      ...
# 5263  Military - Indonesian Air Force      NaN
# 5264                      Service Air      NaN
# 5265                       Air France      447
# 5266                       Strait Air      NaN
# 5267      Military - Indian Air Force      NaN
#
#                                           Route  \
# 0                                 Demonstration
# 1                                   Test flight
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# ...                                         ...
# 5263                           Jakarta - Maduin
# 5264                               Goma - Isiro
# 5265                     Rio de Janeiro - Paris
# 5266  Lourdes de BlanSablon - Port Hope Simpson
# 5267                         Mechuka for Jorhat
#
#                                   Type Registration cn/In  Aboard  Fatalities  \
# 0                     Wright Flyer III          NaN     1     2.0         1.0
# 1                            Dirigible          NaN   NaN     5.0         5.0
# 2                     Curtiss seaplane          NaN   NaN     1.0         1.0
# 3               Zeppelin L-1 (airship)          NaN   NaN    20.0        14.0
# 4               Zeppelin L-2 (airship)          NaN   NaN    30.0        30.0
# ...                                ...          ...   ...     ...         ...
# 5263           Lockheed C-130 Hercules       A-1325  1982   112.0        98.0
# 5264                     Antonov An-26       9Q-CSA  5005     4.0         4.0
# 5265                   Airbus A330-203       F-GZCP   660   228.0       228.0
# 5266  Britten-Norman BN-2A-27 Islander      C-FJJR    424     1.0         1.0
# 5267                     Antonov An-32          NaN   NaN    13.0        13.0
#
#       Ground                                            Summary
# 0        0.0  During a demonstration flight, a U.S. Army fly...
# 1        0.0  First U.S. dirigible Akron exploded just offsh...
# 2        0.0  The first fatal airplane accident in Canada oc...
# 3        0.0  The airship flew into a thunderstorm and encou...
# 4        0.0  Hydrogen gas which was being vented was sucked...
# ...      ...                                                ...
# 5263     2.0  While on approach, the military transport cras...
# 5264     NaN  The cargo plane crashed while on approach to I...
# 5265     0.0  The Airbus went missing over the AtlantiOcean ...
# 5266     0.0  The air ambulance crashed into hills while att...
# 5267     0.0  The military transport went missing while en r...
#
# [5268 rows x 13 columns]

# %%
df.dropna(subset=['Operator'],inplace=True)

# %%
df.drop('Flight #',axis=1,inplace=True)

# %%
df.drop('Route',axis=1,inplace=True)

# %%
df[df.Type.isnull()==True]
# Out:
#             Date     Time     Location                               Operator  \
# 49    04/06/1921  Unknown    australia  Military - Royal Australian Air Force
# 52    05/17/1921  Unknown      wyoming                 US Aerial Mail Service
# 86    11/06/1924  Unknown       france                 Grands Express Aeriens
# 97    09/07/1925  Unknown       france                                  CIDNA
# 114   04/15/1927  Unknown        idaho                       Varney Air Lines
# 220   09/25/1930  Unknown       canada                 Western Canada Airways
# 567   12/11/1941  Unknown      florida                   Pan American Airways
# 632   11/08/1943  Unknown        india            Military - Indian Air Force
# 678   11/09/1944  Unknown       norway         Military - U.S. Army Air Corps
# 717   06/29/1945  Unknown        india      Military - Royal Indian Air Force
# 767   03/17/1946  Unknown        china           Military - Chinese Air Force
# 768   03/18/1946  Unknown        china    China National Aviation Corporation
# 773   04/22/1946  Unknown    nicaragua                                   TACA
# 806   09/20/1946  Unknown        china    China National Aviation Corporation
# 1144  08/08/1951  Unknown    australia               Trans Australia Airlines
# 1190  03/26/1952  Unknown       russia                               Aeroflot
# 1355  12/29/1954  Unknown       russia                               Aeroflot
# 1386  08/06/1955  Unknown       russia                               Aeroflot
# 2289  01/16/1969  Unknown      vietnam                            Air America
# 4399  02/11/1996  Unknown  afghanistan             Military - Taliban Militia
# 5094  04/23/2006    Night       russia                               Yug Avia
#
#      Type Registration  cn/In  Aboard  Fatalities  Ground  \
# 49    NaN        H3021    NaN     2.0         1.0     0.0
# 52    NaN          176    NaN     1.0         1.0     0.0
# 86    NaN       F-AFBD    NaN     1.0         1.0     0.0
# 97    NaN          NaN    NaN     3.0         3.0     0.0
# 114   NaN          NaN    NaN     1.0         1.0     0.0
# 220   NaN          NaN    NaN     3.0         3.0     0.0
# 567   NaN        NC21V    NaN     3.0         3.0     0.0
# 632   NaN          NaN    NaN     1.0         1.0    37.0
# 678   NaN     42-52196    NaN     NaN         NaN     NaN
# 717   NaN          NaN    NaN     2.0         2.0    36.0
# 767   NaN          NaN    NaN    20.0        20.0     0.0
# 768   NaN          139    NaN     NaN         NaN     NaN
# 773   NaN       AN-ACC    NaN    21.0        19.0     0.0
# 806   NaN          NaN    NaN    31.0        31.0     0.0
# 1144  NaN       VH-TAT  13083     2.0         2.0     0.0
# 1190  NaN          NaN    NaN    70.0        70.0     0.0
# 1355  NaN          NaN    NaN    45.0        45.0     0.0
# 1386  NaN          NaN    NaN    25.0        25.0     0.0
# 2289  NaN          949  20415    12.0        12.0     0.0
# 4399  NaN          NaN    NaN    20.0        20.0     0.0
# 5094  NaN     RF-30451    NaN     5.0         4.0     0.0
#
#                                                 Summary
# 49                                                  NaN
# 52                                                  NaN
# 86                                                  NaN
# 97                                                  NaN
# 114   Crashed after an unsuccessful attempt at fly i...
# 220   The air mail plane crashed in fog  while en ro...
# 567                                                 NaN
# 632                             Crashed into a village.
# 678                                                 NaN
# 717   Crashed into a village exploding and destoying...
# 767   Crashed into mountainous terrain in low visibi...
# 768    Disappeared while en route. Plane never located.
# 773                                 Crashed on takeoff.
# 806                 Crashed into a 14,000 ft. mountain.
# 1144  Cargo plane. Loss of lateral control during a ...
# 1190  The plane overshot the runway and collided wit...
# 1355                                                NaN
# 1386                                  Crashed en route.
# 2289  Struck a mountain in poor weather while en route.
# 4399                      The helicopter was shot down.
# 5094  Shortly after takeoff, the pilot made sharp ma...

# %%
df.dropna(subset=['Type'],inplace=True)

# %%
df.drop('Registration',axis=1,inplace=True)

# %%
df.drop('cn/In',axis=1,inplace=True)

# %%
df[df.Ground.isnull()==True]
# Out:
#             Date        Time               Location  \
# 26    10/20/1919     Unknown         englishchannel
# 228   11/18/1930  Late Night             california
# 308   11/09/1933       Night                 oregon
# 310   11/20/1933     Unknown                  china
# 333   08/10/1934     Unknown                  china
# 364   08/13/1935     Unknown                  china
# 423   12/26/1936     Unknown                  china
# 527   11/20/1939     Unknown                england
# 537   07/07/1940     Unknown           gulfoftonkin
# 570   01/24/1942     Unknown                 borneo
# 571   01/26/1942     Unknown                  timor
# 573   02/14/1942     Unknown                Unknown
# 593   10/01/1942     Unknown                  china
# 643   03/22/1944     Unknown              newguinea
# 1177  02/07/1952     Unknown                  japan
# 1186  03/12/1952     Unknown                  texas
# 1822  12/20/1962     Unknown                okinawa
# 4705  03/22/2000     Unknown                  spain
# 4709  06/23/2000     Morning                florida
# 5264  05/26/2009     Unknown  democratirepublicongo
#
#                                         Operator                         Type  \
# 26                 Aircraft Transport and Travel            De Havilland DH-4
# 228                          PacifiAir Transport                    Boeing 40
# 308                             United Air Lines                   Boeing 247
# 310          China National Aviation Corporation                       Sinson
# 333          China National Aviation Corporation               Sikorsky S-38B
# 364          China National Aviation Corporation               Sikorsky S-38B
# 423          China National Aviation Corporation                 Douglas DC-2
# 527                              British Airways              Airspeed Oxford
# 537                                   Air France              Dewoitine D-338
# 570                                        KNILM                 Douglas DC-3
# 571                                        KNILM           Grumman G-21 Goose
# 573          China National Aviation Corporation                 Douglas DC-2
# 593          China National Aviation Corporation                 Douglas C-47
# 643                         Military - U.S. Army  Consolidated B-24 Liberator
# 1177                   Military - U.S. Air Force                  Boeing B-29
# 1186  Military - U.S. Air Force / U.S. Air Force    Boeing B-29 / Boeing B-29
# 1822                   Military - U.S. Air Force                        KB-50
# 4705                Military - Ejército del Aire      CASA 212-DE Aviocar 200
# 4709                      Universal Jet Aviation                   Learjet 55
# 5264                                 Service Air                Antonov An-26
#
#       Aboard  Fatalities  Ground  \
# 26       NaN         NaN     NaN
# 228      3.0         3.0     NaN
# 308      9.0         4.0     NaN
# 310      8.0         8.0     NaN
# 333      NaN         NaN     NaN
# 364      NaN         NaN     NaN
# 423      NaN         NaN     NaN
# 527      2.0         2.0     NaN
# 537      NaN         NaN     NaN
# 570      NaN         NaN     NaN
# 571      NaN         NaN     NaN
# 573      NaN         NaN     NaN
# 593      NaN         NaN     NaN
# 643     21.0        21.0     NaN
# 1177    17.0        17.0     NaN
# 1186    15.0        15.0     NaN
# 1822    12.0        12.0     NaN
# 4705     NaN         NaN     NaN
# 4709     3.0         3.0     NaN
# 5264     4.0         4.0     NaN
#
#                                                 Summary
# 26                                                  NaN
# 228   Crashed into a mountainside at an altitude of ...
# 308   Crashed in a thickly wooded area upon taking o...
# 310   Crashed into the Chingshan mountain range in fog.
# 333                                                 NaN
# 364                               Destoryed in a storm.
# 423                                                 NaN
# 527                                                 NaN
# 537           Shot down by a Japanese military fighter.
# 570            Shot down by Japanese military aircraft.
# 571            Shot down by Japanese military aircraft.
# 573                                                 NaN
# 593   Crashed while attempting to land after losing ...
# 643   Disappeared while en route on a non-combat mis...
# 1177  Hit power lines and crashed into houses. Seven...
# 1186  While on a training mission and flying blind o...
# 1822  Twelve killed, including civilians. Two civili...
# 4705  Crashed while attempting to land in poor weather.
# 4709  Shortly after takeoff the aircraft impacted an...
# 5264  The cargo plane crashed while on approach to I...

# %%
df.Ground=df.Ground.fillna(df.Ground.median())

# %%
df[df.Aboard.isnull()==True]
# Out:
#             Date     Time                          Location  \
# 26    10/20/1919  Unknown                    englishchannel
# 333   08/10/1934  Unknown                             china
# 348   03/07/1935  Unknown                           germany
# 364   08/13/1935  Unknown                             china
# 423   12/26/1936  Unknown                             china
# 526   09/26/1939  Unknown                          northsea
# 537   07/07/1940  Unknown                      gulfoftonkin
# 570   01/24/1942  Unknown                            borneo
# 571   01/26/1942  Unknown                             timor
# 573   02/14/1942  Unknown                           Unknown
# 587   08/13/1942  Unknown                           algeria
# 593   10/01/1942  Unknown                             china
# 832   12/25/1946  Unknown                             china
# 1479  04/20/1957  Unknown                              iraq
# 3007  11/03/1977  Unknown                        yugoslavia
# 3323  12/16/1981  Unknown                            brunei
# 3369  08/11/1982  Unknown                       pacifiocean
# 3843  05/09/1989  Unknown                             china
# 4080  02/20/1992  Unknown  enroutefromargentinatocalifornia
# 4705  03/22/2000  Unknown                             spain
#
#                                  Operator                             Type  \
# 26          Aircraft Transport and Travel                De Havilland DH-4
# 333   China National Aviation Corporation                   Sikorsky S-38B
# 348                              Deruluft                 Rochrbach Roland
# 364   China National Aviation Corporation                   Sikorsky S-38B
# 423   China National Aviation Corporation                     Douglas DC-2
# 526              KLM Royal Dutch Airlines                     Douglas DC-3
# 537                            Air France                  Dewoitine D-338
# 570                                 KNILM                     Douglas DC-3
# 571                                 KNILM               Grumman G-21 Goose
# 573   China National Aviation Corporation                     Douglas DC-2
# 587                            Air France  Liore et Olivier H-246 Air Boat
# 593   China National Aviation Corporation                     Douglas C-47
# 832   China National Aviation Corporation         Curtiss C-46, C-47, DC-3
# 1479                           Air France     Lockheed Super Constellation
# 3007                                El Al                     Boeing B-747
# 3323                  Bristow Helicopters                Aerospatiale Puma
# 3369           Pan American World Airways                 Boeing B-747-121
# 3843                           Aero Asahi                         Bell 412
# 4080                Aerolineas Argentinas                     Boeing B-747
# 4705         Military - Ejército del Aire          CASA 212-DE Aviocar 200
#
#       Aboard  Fatalities  Ground  \
# 26       NaN         NaN     0.0
# 333      NaN         NaN     0.0
# 348      NaN         3.0     0.0
# 364      NaN         NaN     0.0
# 423      NaN         NaN     0.0
# 526      NaN         1.0     0.0
# 537      NaN         NaN     0.0
# 570      NaN         NaN     0.0
# 571      NaN         NaN     0.0
# 573      NaN         NaN     0.0
# 587      NaN         4.0     0.0
# 593      NaN         NaN     0.0
# 832      NaN        87.0     4.0
# 1479     NaN         1.0     0.0
# 3007     NaN         1.0     0.0
# 3323     NaN        12.0     0.0
# 3369     NaN         1.0     0.0
# 3843     NaN        10.0     0.0
# 4080     NaN         1.0     0.0
# 4705     NaN         NaN     0.0
#
#                                                 Summary
# 26                                                  NaN
# 333                                                 NaN
# 348                                   Fuselage failure.
# 364                               Destoryed in a storm.
# 423                                                 NaN
# 526   One Swedish passenger was killed when the plan...
# 537           Shot down by a Japanese military fighter.
# 570            Shot down by Japanese military aircraft.
# 571            Shot down by Japanese military aircraft.
# 573                                                 NaN
# 587   Attacked by Royal Air Force fighters.  Crashed...
# 593   Crashed while attempting to land after losing ...
# 832   Various accidents involving three aircraft una...
# 1479  Explosive decompression. A passenger was sucke...
# 3007                           Explosive decompression.
# 3323                                                NaN
# 3369  A sixteen-year-old boy was killed when a bomb ...
# 3843                                                NaN
# 4080        A passenger died of cholera while en route.
# 4705  Crashed while attempting to land in poor weather.

# %%
# Dropping rows where any aboard and fatalities are having NAN values 
# because they dont have any value to our purpose.
df.dropna(subset=['Aboard','Fatalities'],how='any',inplace=True)

# %%
df
# Out:
#             Date           Time               Location  \
# 0     09/17/1908        Evening               virginia
# 1     07/12/1912  Early Morning              newjersey
# 2     08/06/1913        Unknown                 canada
# 3     09/09/1913        Evening        overthenorthsea
# 4     10/17/1913        Morning                germany
# ...          ...            ...                    ...
# 5263  05/20/2009  Early Morning              indonesia
# 5264  05/26/2009        Unknown  democratirepublicongo
# 5265  06/01/2009     Late Night                 brazil
# 5266  06/07/2009  Early Morning                 canada
# 5267  06/08/2009        Unknown                  india
#
#                              Operator                              Type  \
# 0                Military - U.S. Army                  Wright Flyer III
# 1                Military - U.S. Navy                         Dirigible
# 2                             Private                  Curtiss seaplane
# 3              Military - German Navy            Zeppelin L-1 (airship)
# 4              Military - German Navy            Zeppelin L-2 (airship)
# ...                               ...                               ...
# 5263  Military - Indonesian Air Force           Lockheed C-130 Hercules
# 5264                      Service Air                     Antonov An-26
# 5265                       Air France                   Airbus A330-203
# 5266                       Strait Air  Britten-Norman BN-2A-27 Islander
# 5267      Military - Indian Air Force                     Antonov An-32
#
#       Aboard  Fatalities  Ground  \
# 0        2.0         1.0     0.0
# 1        5.0         5.0     0.0
# 2        1.0         1.0     0.0
# 3       20.0        14.0     0.0
# 4       30.0        30.0     0.0
# ...      ...         ...     ...
# 5263   112.0        98.0     2.0
# 5264     4.0         4.0     0.0
# 5265   228.0       228.0     0.0
# 5266     1.0         1.0     0.0
# 5267    13.0        13.0     0.0
#
#                                                 Summary
# 0     During a demonstration flight, a U.S. Army fly...
# 1     First U.S. dirigible Akron exploded just offsh...
# 2     The first fatal airplane accident in Canada oc...
# 3     The airship flew into a thunderstorm and encou...
# 4     Hydrogen gas which was being vented was sucked...
# ...                                                 ...
# 5263  While on approach, the military transport cras...
# 5264  The cargo plane crashed while on approach to I...
# 5265  The Airbus went missing over the AtlantiOcean ...
# 5266  The air ambulance crashed into hills while att...
# 5267  The military transport went missing while en r...
#
# [5209 rows x 9 columns]

# %%
df.dropna(subset=["Summary"],inplace=True)

# %%
df.shape
# Out:
# (4835, 9)

# %%
# Returns only year.
def get_year(date):
    return date.split('/')[2]

# %%
df.Date=df.Date.apply(get_year)

# %%
df
# Out:
#       Date           Time               Location  \
# 0     1908        Evening               virginia
# 1     1912  Early Morning              newjersey
# 2     1913        Unknown                 canada
# 3     1913        Evening        overthenorthsea
# 4     1913        Morning                germany
# ...    ...            ...                    ...
# 5263  2009  Early Morning              indonesia
# 5264  2009        Unknown  democratirepublicongo
# 5265  2009     Late Night                 brazil
# 5266  2009  Early Morning                 canada
# 5267  2009        Unknown                  india
#
#                              Operator                              Type  \
# 0                Military - U.S. Army                  Wright Flyer III
# 1                Military - U.S. Navy                         Dirigible
# 2                             Private                  Curtiss seaplane
# 3              Military - German Navy            Zeppelin L-1 (airship)
# 4              Military - German Navy            Zeppelin L-2 (airship)
# ...                               ...                               ...
# 5263  Military - Indonesian Air Force           Lockheed C-130 Hercules
# 5264                      Service Air                     Antonov An-26
# 5265                       Air France                   Airbus A330-203
# 5266                       Strait Air  Britten-Norman BN-2A-27 Islander
# 5267      Military - Indian Air Force                     Antonov An-32
#
#       Aboard  Fatalities  Ground  \
# 0        2.0         1.0     0.0
# 1        5.0         5.0     0.0
# 2        1.0         1.0     0.0
# 3       20.0        14.0     0.0
# 4       30.0        30.0     0.0
# ...      ...         ...     ...
# 5263   112.0        98.0     2.0
# 5264     4.0         4.0     0.0
# 5265   228.0       228.0     0.0
# 5266     1.0         1.0     0.0
# 5267    13.0        13.0     0.0
#
#                                                 Summary
# 0     During a demonstration flight, a U.S. Army fly...
# 1     First U.S. dirigible Akron exploded just offsh...
# 2     The first fatal airplane accident in Canada oc...
# 3     The airship flew into a thunderstorm and encou...
# 4     Hydrogen gas which was being vented was sucked...
# ...                                                 ...
# 5263  While on approach, the military transport cras...
# 5264  The cargo plane crashed while on approach to I...
# 5265  The Airbus went missing over the AtlantiOcean ...
# 5266  The air ambulance crashed into hills while att...
# 5267  The military transport went missing while en r...
#
# [4835 rows x 9 columns]

# %%
df.Date=df.Date.astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4835 entries, 0 to 5267
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Date        4835 non-null   int32
#  1   Time        4835 non-null   object
#  2   Location    4835 non-null   object
#  3   Operator    4835 non-null   object
#  4   Type        4835 non-null   object
#  5   Aboard      4835 non-null   float64
#  6   Fatalities  4835 non-null   float64
#  7   Ground      4835 non-null   float64
#  8   Summary     4835 non-null   object
# dtypes: float64(3), int32(1), object(5)
# memory usage: 358.8+ KB

# %%
crshs=pd.DataFrame(df.Date.value_counts())

plt.figure(figsize=(15, 5))
plt.bar(x=crshs.index, height=crshs["Date"])
plt.title("Number of Crashes each Year")
plt.show()

# %%
abor=pd.DataFrame(df.Aboard.groupby(df.Date).sum())

plt.figure(figsize=(15, 5))
plt.bar(x=abor.index, height=abor["Aboard"])
plt.title("Number of People Aboard each Year")
plt.show()

# %%
fatals=pd.DataFrame(df.Fatalities.groupby(df.Date).sum())

plt.figure(figsize=(15, 5))
plt.bar(x=fatals.index, height=fatals["Fatalities"])
plt.title("Number of People died in Plane each Year")
plt.show()

# %%
grd=pd.DataFrame(df.Ground.groupby(df.Date).sum())

plt.figure(figsize=(15, 5))
plt.bar(x=grd.index, height=grd["Ground"])
plt.title("Number of People died in Ground each Year")
plt.show()

# %%
sur=pd.DataFrame({"Survived":df.Aboard-df.Fatalities},index=df.Date).index.value_counts()

plt.figure(figsize=(15, 5))
plt.bar(x=sur.index, height=sur.values)
plt.title("Number of People survived each Year")
plt.show()

# %%
ded=pd.DataFrame({"Dead":df.Fatalities+df.Ground},index=df.Date).index.value_counts()

plt.figure(figsize=(15, 5))
plt.bar(x=ded.index, height=ded.values)
plt.title("Number of People Died each Year")
plt.show()

# %%
# Top 7 Plane Operators which involved in crashes.
pd.DataFrame(df.Operator.value_counts().sort_values(ascending=False)[:10])
# Out:
#                                  Operator
# Military - U.S. Air Force             170
# Aeroflot                              163
# Air France                             60
# Deutsche Lufthansa                     51
# Air Taxi                               44
# United Air Lines                       44
# Military - U.S. Army Air Forces        43
# Pan American World Airways             40
# American Airlines                      36
# Military - U.S. Navy                   35

# %%
pd.DataFrame(df.Type.value_counts().sort_values(ascending=False))[:10]
# Out:
#                                           Type
# Douglas DC-3                               318
# de Havilland Canada DHC-6 Twin Otter 300    79
# Douglas C-47A                               69
# Douglas C-47                                57
# Douglas DC-4                                39
# Yakovlev YAK-40                             36
# Antonov AN-26                               34
# Douglas DC-6B                               26
# Douglas C-47B                               26
# Junkers JU-52/3m                            25

# %%
pd.DataFrame(df.Location.value_counts().sort_values(ascending=False))[:10]
# Out:
#             Location
# alaska           175
# brazil           173
# russia           162
# colombia         140
# california       140
# canada           138
# france           108
# india             92
# england           90
# indonesia         80

# %%
plt.figure(figsize=(15, 5))
sns.countplot(x=df.Time)
plt.title("Time of Day VS Number of Crashes")
plt.show()

# %%
plt.figure(figsize=(15, 5))
sns.barplot(data=df, x=df.Time, y=df.Aboard)
plt.title("Time of Day VS People onboard")
plt.show()

# %%
plt.figure(figsize=(15, 5))
sns.barplot(data=df, x=df.Time, y=df.Fatalities)
plt.title("Time of Day VS Fatalities")
plt.show()

# %%
# Analyzing Quantitative variables.
plt.figure(figsize=(30, 5))
ind = 1

for col in df.loc[:,'Aboard':'Ground'].columns:
    plt.subplot(1, 3, ind)
    sns.boxplot(x=df[col])
    ind += 1

# %%
df['Time_Of_Day']=df.Time.replace({"Unknown":0, "Late Night":1, "Early Morning":2, "Morning":3,
                                   "Noon":4, "Evening":5, "Night":6})

# %%
df
# Out:
#       Date           Time               Location  \
# 0     1908        Evening               virginia
# 1     1912  Early Morning              newjersey
# 2     1913        Unknown                 canada
# 3     1913        Evening        overthenorthsea
# 4     1913        Morning                germany
# ...    ...            ...                    ...
# 5263  2009  Early Morning              indonesia
# 5264  2009        Unknown  democratirepublicongo
# 5265  2009     Late Night                 brazil
# 5266  2009  Early Morning                 canada
# 5267  2009        Unknown                  india
#
#                              Operator                              Type  \
# 0                Military - U.S. Army                  Wright Flyer III
# 1                Military - U.S. Navy                         Dirigible
# 2                             Private                  Curtiss seaplane
# 3              Military - German Navy            Zeppelin L-1 (airship)
# 4              Military - German Navy            Zeppelin L-2 (airship)
# ...                               ...                               ...
# 5263  Military - Indonesian Air Force           Lockheed C-130 Hercules
# 5264                      Service Air                     Antonov An-26
# 5265                       Air France                   Airbus A330-203
# 5266                       Strait Air  Britten-Norman BN-2A-27 Islander
# 5267      Military - Indian Air Force                     Antonov An-32
#
#       Aboard  Fatalities  Ground  \
# 0        2.0         1.0     0.0
# 1        5.0         5.0     0.0
# 2        1.0         1.0     0.0
# 3       20.0        14.0     0.0
# 4       30.0        30.0     0.0
# ...      ...         ...     ...
# 5263   112.0        98.0     2.0
# 5264     4.0         4.0     0.0
# 5265   228.0       228.0     0.0
# 5266     1.0         1.0     0.0
# 5267    13.0        13.0     0.0
#
#                                                 Summary  Time_Of_Day
# 0     During a demonstration flight, a U.S. Army fly...            5
# 1     First U.S. dirigible Akron exploded just offsh...            2
# 2     The first fatal airplane accident in Canada oc...            0
# 3     The airship flew into a thunderstorm and encou...            5
# 4     Hydrogen gas which was being vented was sucked...            3
# ...                                                 ...          ...
# 5263  While on approach, the military transport cras...            2
# 5264  The cargo plane crashed while on approach to I...            0
# 5265  The Airbus went missing over the AtlantiOcean ...            1
# 5266  The air ambulance crashed into hills while att...            2
# 5267  The military transport went missing while en r...            0
#
# [4835 rows x 10 columns]

# %%
df_quant=[col for col in df.columns if df[col].dtype != object]
df_quant=df[df_quant]
df_quant.head(2)
# Out:
#    Date  Aboard  Fatalities  Ground  Time_Of_Day
# 0  1908     2.0         1.0     0.0            5
# 1  1912     5.0         5.0     0.0            2

# %%
from sklearn.preprocessing import StandardScaler
def data_scaling(dataframe,inverse=False):
    scaler=StandardScaler()
    
    if inverse == False:
        return scaler.fit_transform(dataframe)
    else:
        scaler.fit(dataframe)
        return scaler.inverse_transform(dataframe)

# %%
df_quant_scaled=data_scaling(df_quant)

# %%
from sklearn.cluster import KMeans

# Obtain optimal number of clusters
scores_1 = []

range_values = range(1, 10)

for i in range_values:
  kmeans = KMeans(n_clusters = i)
  kmeans.fit(df_quant_scaled)
  scores_1.append(kmeans.inertia_) 

plt.plot(scores_1, 'bx-')
plt.title('Finding the right number of clusters')
plt.xlabel('Clusters')
plt.ylabel('Scores') 
plt.show()

# %%
# Build the KMeans model
kmeans = KMeans(3)
kmeans.fit(df_quant_scaled)
# Out:
# KMeans(n_clusters=3)

# %%
cluster_centers = pd.DataFrame(data = kmeans.cluster_centers_, columns = [df_quant.columns])
cluster_centers
# Out:
#        Date    Aboard Fatalities     Ground Time_Of_Day
# 0 -0.046321 -0.236735  -0.221832  -0.021375   -0.049676
# 1  0.476730  2.462795   2.304801  -0.008269    0.516370
# 2  1.309412  1.118909   1.674215  48.880965    0.324189

# %%
cluster_centers = data_scaling(cluster_centers,inverse=True)
cluster_centers = pd.DataFrame(data = cluster_centers, columns = [df_quant.columns])
cluster_centers
# Out:
#        Date    Aboard Fatalities       Ground Time_Of_Day
# 0  0.554081  0.854089   1.014202    15.791084    0.251952
# 1  0.846082  3.829191   3.727182    16.093180    0.384986
# 2  1.310941  2.348119   3.050088  1142.975153    0.339819

# %%
# concatenate the clusters labels to our original dataframe
df_cluster = pd.concat([df, pd.DataFrame({'cluster':kmeans.labels_})], axis = 1)
df_cluster.head()
# Out:
#      Date           Time         Location                Operator  \
# 0  1908.0        Evening         virginia    Military - U.S. Army
# 1  1912.0  Early Morning        newjersey    Military - U.S. Navy
# 2  1913.0        Unknown           canada                 Private
# 3  1913.0        Evening  overthenorthsea  Military - German Navy
# 4  1913.0        Morning          germany  Military - German Navy
#
#                      Type  Aboard  Fatalities  Ground  \
# 0        Wright Flyer III     2.0         1.0     0.0
# 1               Dirigible     5.0         5.0     0.0
# 2        Curtiss seaplane     1.0         1.0     0.0
# 3  Zeppelin L-1 (airship)    20.0        14.0     0.0
# 4  Zeppelin L-2 (airship)    30.0        30.0     0.0
#
#                                              Summary  Time_Of_Day  cluster
# 0  During a demonstration flight, a U.S. Army fly...          5.0      0.0
# 1  First U.S. dirigible Akron exploded just offsh...          2.0      0.0
# 2  The first fatal airplane accident in Canada oc...          0.0      0.0
# 3  The airship flew into a thunderstorm and encou...          5.0      0.0
# 4  Hydrogen gas which was being vented was sucked...          3.0      0.0

# %%
pd.crosstab(index=df_cluster['cluster'],columns='count')
# Out:
# col_0    count
# cluster
# 0.0       4410
# 1.0        423
# 2.0          2

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=2)
principal_comp = pca.fit_transform(df_quant_scaled)
principal_comp
# Out:
# array([[-1.16366746,  1.01927306],
#        [-1.36655202,  1.82645246],
#        [-1.73808436,  2.33588731],
#        ...,
#        [ 7.19127195,  1.86396468],
#        [-0.46701269, -1.3587852 ],
#        [-0.30080281, -0.61079955]])

# %%
pca_df = pd.DataFrame(data = principal_comp, columns =['pca1','pca2'])
pca_df.head()
# Out:
#        pca1      pca2
# 0 -1.163667  1.019273
# 1 -1.366552  1.826452
# 2 -1.738084  2.335887
# 3 -0.589273  1.050873
# 4 -0.376388  1.819753

# %%
pca_df = pd.concat([pca_df,pd.DataFrame({'cluster':kmeans.labels_})], axis = 1)
pca_df.head()
# Out:
#        pca1      pca2  cluster
# 0 -1.163667  1.019273        0
# 1 -1.366552  1.826452        0
# 2 -1.738084  2.335887        0
# 3 -0.589273  1.050873        0
# 4 -0.376388  1.819753        0

# %%
plt.figure(figsize=(10,10))
ax = sns.scatterplot(x="pca1", y="pca2", hue = "cluster", data = pca_df, palette =['red','green','blue'])
plt.show()

# %%
pca.explained_variance_ratio_
# Out:
# array([0.36900472, 0.22799941])
